# %%
import re, os, json

def label_to_price_per_kg(label):
    regex = r'Euro (\d+,\d+) \/ ([a-z]+)'
    match = re.match(regex, label)
    
    if not match:
        return None
    
    groups = list(match.groups())
    price_per_kg = float(groups[0].replace(',', '.'))
    
    # Adjust price per kg if necessary
    if groups[1] == 'g' or groups[1] == 'ml':
        price_per_kg *= 1000
    elif groups[1] == 'hg':
        price_per_kg *= 10
    elif groups[1] == 'pz':
        price_per_kg = None
    
    return price_per_kg

def parse_har(har_filename):
    # Parse har as json
    with open('har/{}'.format(har_filename)) as f:
        js = json.loads(f.read())
    
    # Iterate over responses and get all the entities
    entities = []
    for entry in js['log']['entries']:
        response = json.loads(entry['response']['content']['text'])
        entities.extend(response['entities'])
        
    for entity in entities:
        # Strip description
        entity['description'] = entity['description'].strip()
        
        # Calculate price per kg by parsing the label
        entity['price_per_kg'] = label_to_price_per_kg(entity['label'])
        
        # Add qty
        entity['qty'] = ' '.join([entity['unitValue'], entity['unitText']])
        
        # Add category
        entity['category'] = har_filename[:-4]

        # Only keep products with price per kg
    entities = list(filter(lambda entity: entity['price_per_kg'], entities))
    
    # Keep only interesting keys
    keys_to_keep = ['description', 'category', 'price', 'qty', 'price_per_kg']
    
    # Create dictionary with product id as key
    entities = { entity['id'] : { k: entity[k] for k in keys_to_keep } for entity in entities }
    
    return entities

# %%
# Database creation

entities = {}
limit = 100
for har_filename in next(os.walk('har'))[2]:
    entities.update(parse_har(har_filename))

# Print
for elem, index in list(zip(entities, range(limit))): 
    print(entities[elem])
# Out:
# {'description': 'Esselunga, suino salsiccia', 'category': 'carne', 'price': 7.49, 'qty': '1 kg', 'price_per_kg': 7.49}
# {'description': 'Esselunga, macinata mista di bovino e suino', 'category': 'carne', 'price': 7.59, 'qty': '1 kg', 'price_per_kg': 7.59}
# {'description': 'Esselunga Naturama, petto di pollo a fette allevato senza uso di antibiotici', 'category': 'carne', 'price': 12.49, 'qty': '1 kg', 'price_per_kg': 9.99}
# {'description': 'Esselunga, vitello fegato a fette', 'category': 'carne', 'price': 17.14, 'qty': '1 kg', 'price_per_kg': 11.99}
# {'description': 'Esselunga Naturama, petto di pollo fettine sottili allevato senza uso di antibiotici', 'category': 'carne', 'price': 14.2, 'qty': '1 kg', 'price_per_kg': 14.2}
# {'description': 'Esselunga Naturama, mini filetti di pollo allevato senza uso di antibiotici', 'category': 'carne', 'price': 10.99, 'qty': '1 kg', 'price_per_kg': 10.99}
# {'description': 'Esselunga Naturama, sovracosce di pollo senza pelle allevato senza uso di antibiotici', 'category': 'carne', 'price': 6.62, 'qty': '1 kg', 'price_per_kg': 5.29}
# {'description': 'Esselunga, bovino adulto filetto al pepe verde', 'category': 'carne', 'price': 33.25, 'qty': '1 kg', 'price_per_kg': 26.6}
# {'description': 'Esselunga, tacchino fesa a fette', 'category': 'carne', 'price': 11.69, 'qty': '1 kg', 'price_per_kg': 11.69}
# {'description': 'Esselunga Naturama, alette di pollo allevato senza uso di antibiotici', 'category': 'carne', 'price': 3.79, 'qty': '1 kg', 'price_per_kg': 3.79}
# {'description': 'Esselunga, suino fettine di coppa (scamerita a fette)', 'category': 'carne', 'price': 7.29, 'qty': '1 kg', 'price_per_kg': 7.29}
# {'description': 'Esselunga, suino puntine (rosticciana) confezione risparmio', 'category': 'carne', 'price': 5.49, 'qty': '1 kg', 'price_per_kg': 5.49}
# {'description': 'Esselunga, sovracosce senza pelle di pollo ad alimentazione vegetale', 'category': 'carne', 'price': 6.29, 'qty': '1 kg', 'price_per_kg': 6.29}
# {'description': 'Esselunga, suino fettine di lonza (arista) disossata confezione risparmio', 'category': 'carne', 'price': 8.59, 'qty': '1 kg', 'price_per_kg': 8.59}
# {'description': 'Esselunga, fusi di pollo ad alimentazione vegetale', 'category': 'carne', 'price': 5.99, 'qty': '1 kg', 'price_per_kg': 5.99}
# {'description': 'Esselunga, suino trita (macinata)', 'category': 'carne', 'price': 5.89, 'qty': '1 kg', 'price_per_kg': 5.89}
# {'description': 'Esselunga, bovino adulto carne trita (macinata) scelta confezione risparmio', 'category': 'carne', 'price': 9.25, 'qty': '1 kg', 'price_per_kg': 7.4}
# {'description': 'Esselunga, bovino adulto trippa tagliata', 'category': 'carne', 'price': 5.85, 'qty': '1 kg', 'price_per_kg': 5.85}
# {'description': 'Esselunga Naturama, straccetti petto di pollo allevato senza uso di antibiotici', 'category': 'carne', 'price': 10.49, 'qty': '1 kg', 'price_per_kg': 10.49}
# {'description': 'Esselunga, pollo fegati', 'category': 'carne', 'price': 4.1, 'qty': '1 kg', 'price_per_kg': 4.1}
# {'description': 'Esselunga Naturama, fusi di pollo allevato senza uso di antibiotici', 'category': 'carne', 'price': 6.37, 'qty': '1 kg', 'price_per_kg': 5.09}
# {'description': 'Esselunga, pollo durelli', 'category': 'carne', 'price': 3.95, 'qty': '1 kg', 'price_per_kg': 3.95}
# {'description': 'Esselunga Naturama, fettine sottili di fesa di tacchino ad alimentazione vegetale', 'category': 'carne', 'price': 13.99, 'qty': '1 kg', 'price_per_kg': 13.99}
# {'description': 'Esselunga, suino salamella mantovana 3 pezzi', 'category': 'carne', 'price': 8.99, 'qty': '1 kg', 'price_per_kg': 8.99}
# {'description': 'Esselunga, suino lonza (arista) disossata', 'category': 'carne', 'price': 7.42, 'qty': '1 kg', 'price_per_kg': 5.19}
# {'description': 'Esselunga, vitello cuore a fette', 'category': 'carne', 'price': 6.4, 'qty': '1 kg', 'price_per_kg': 6.4}
# {'description': 'Esselunga, metà coniglio porzionato', 'category': 'carne', 'price': 9.49, 'qty': '1 kg', 'price_per_kg': 9.49}
# {'description': 'Esselunga, tacchino ali 2 pezzi', 'category': 'carne', 'price': 2.35, 'qty': '1 kg', 'price_per_kg': 2.35}
# {'description': 'Esselunga Naturama, petto di pollo allevato senza uso di antibiotici', 'category': 'carne', 'price': 8.99, 'qty': '1 kg', 'price_per_kg': 8.99}
# {'description': 'Esselunga, suino salsiccia piccante', 'category': 'carne', 'price': 7.39, 'qty': '1 kg', 'price_per_kg': 7.39}
# {'description': 'Esselunga, suino salsiccia punta di coltello', 'category': 'carne', 'price': 8.99, 'qty': '1 kg', 'price_per_kg': 8.99}
# {'description': 'Esselunga, suino filetto', 'category': 'carne', 'price': 9.99, 'qty': '1 kg', 'price_per_kg': 9.99}
# {'description': 'Esselunga, suino Baby Ribs puntine', 'category': 'carne', 'price': 8.99, 'qty': '1 kg', 'price_per_kg': 8.99}
# {'description': "Esselunga Naturama, coniglio a meta' in parti ad alimentazione vegetale", 'category': 'carne', 'price': 9.99, 'qty': '1 kg', 'price_per_kg': 9.99}
# {'description': 'Esselunga, mezzi filetti di pollo ad alimentazione vegetale', 'category': 'carne', 'price': 9.99, 'qty': '1 kg', 'price_per_kg': 9.99}
# {'description': 'Esselunga, suino verzini', 'category': 'carne', 'price': 7.29, 'qty': '1 kg', 'price_per_kg': 7.29}
# {'description': 'Esselunga, bovino adulto trippa foiolo', 'category': 'carne', 'price': 6.99, 'qty': '1 kg', 'price_per_kg': 6.99}
# {'description': 'Esselunga Hamburgeria, bovino adulto razza piemontese hamburger classici 250 g', 'category': 'carne', 'price': 4.49, 'qty': '250 g', 'price_per_kg': 14.36}
# {'description': 'Esselunga, suino braciole di coppa (scamerita con osso) confezione risparmio', 'category': 'carne', 'price': 5.89, 'qty': '1 kg', 'price_per_kg': 5.89}
# {'description': 'Esselunga, tacchino sovracoscia', 'category': 'carne', 'price': 4.4, 'qty': '1 kg', 'price_per_kg': 4.4}
# {'description': 'Esselunga, gallina a busto', 'category': 'carne', 'price': 3.59, 'qty': '1 kg', 'price_per_kg': 3.59}
# {'description': "Esselunga, gallina a meta'", 'category': 'carne', 'price': 3.99, 'qty': '1 kg', 'price_per_kg': 3.99}
# {'description': 'Esselunga, suino fettine sottili di tagliata di lonza (arista) disossata', 'category': 'carne', 'price': 10.59, 'qty': '1 kg', 'price_per_kg': 10.59}
# {'description': 'Esselunga, coscette di pollo ad alimentazione vegetale', 'category': 'carne', 'price': 5.79, 'qty': '1 kg', 'price_per_kg': 5.79}
# {'description': 'Esselunga, tacchino per paillard 200 g', 'category': 'carne', 'price': 3.59, 'qty': '200 g', 'price_per_kg': 17.95}
# {'description': "Esselunga, tacchino fesa a meta'", 'category': 'carne', 'price': 8.24, 'qty': '1 kg', 'price_per_kg': 8.24}
# {'description': 'Esselunga, cosce di coniglio', 'category': 'carne', 'price': 9.1, 'qty': '1 kg', 'price_per_kg': 9.1}
# {'description': 'Esselunga Naturama, pollo busto allevato senza uso di antibiotici', 'category': 'carne', 'price': 4.75, 'qty': '1 kg', 'price_per_kg': 4.75}
# {'description': 'Esselunga, suino coppa (scamerita) disossata', 'category': 'carne', 'price': 6.99, 'qty': '1 kg', 'price_per_kg': 6.99}
# {'description': 'Esselunga, coniglio lombatine', 'category': 'carne', 'price': 8.89, 'qty': '1 kg', 'price_per_kg': 8.89}
# {'description': 'Esselunga, spedini con pollo e alloro', 'category': 'carne', 'price': 10.5, 'qty': '1 kg', 'price_per_kg': 8.4}
# {'description': 'Esselunga Naturama, pollo griglia allevato senza uso di antibiotici', 'category': 'carne', 'price': 4.84, 'qty': '1 kg', 'price_per_kg': 2.9}
# {'description': 'Esselunga, suino tagliata di lonza (arista) salvia e rosmarino', 'category': 'carne', 'price': 11.42, 'qty': '1 kg', 'price_per_kg': 7.99}
# {'description': 'Esselunga, coniglio spalle 2 pezzi', 'category': 'carne', 'price': 6.45, 'qty': '1 kg', 'price_per_kg': 6.45}
# {'description': 'Esselunga, suino spiedini confezione risparmio', 'category': 'carne', 'price': 8.29, 'qty': '1 kg', 'price_per_kg': 8.29}
# {'description': 'Esselunga Naturama, bocconcini  petto di pollo allevato senza uso di antibiotici', 'category': 'carne', 'price': 10.49, 'qty': '1 kg', 'price_per_kg': 10.49}
# {'description': 'Esselunga, suino arrosticini 400 g', 'category': 'carne', 'price': 4.99, 'qty': '400 g', 'price_per_kg': 8.73}
# {'description': 'Esselunga, tacchino spezzatino', 'category': 'carne', 'price': 6.89, 'qty': '1 kg', 'price_per_kg': 6.89}
# {'description': 'Esselunga Hamburgeria, vitello svizzere con parmigiano reggiano 250 g', 'category': 'carne', 'price': 4.29, 'qty': '250 g', 'price_per_kg': 17.16}
# {'description': 'Esselunga Hamburgeria, bovino adulto razza piemontese maxi hamburger con parmigiano reggiano 220 g', 'category': 'carne', 'price': 4.3, 'qty': '220 g', 'price_per_kg': 19.55}
# {'description': 'Esselunga, tacchino coscia', 'category': 'carne', 'price': 3.75, 'qty': '1 kg', 'price_per_kg': 3.75}
# {'description': 'Esselunga, vitello lingua', 'category': 'carne', 'price': 12.89, 'qty': '1 kg', 'price_per_kg': 12.89}
# {'description': 'Esselunga, suino cotolette (bistecche nella costola) 2 pezzi', 'category': 'carne', 'price': 6.29, 'qty': '1 kg', 'price_per_kg': 6.29}
# {'description': 'Esselunga, suino costine (rosticciana) per griglia con rosmarino', 'category': 'carne', 'price': 7.99, 'qty': '1 kg', 'price_per_kg': 7.99}
# {'description': "Esselunga Naturama, roast beef (lombata senz'osso) a fette", 'category': 'carne', 'price': 20.5, 'qty': '1 kg', 'price_per_kg': 20.5}
# {'description': 'Esselunga Naturama, bocconcini di fesa di tacchino ad alimentazione vegetale', 'category': 'carne', 'price': 11.19, 'qty': '1 kg', 'price_per_kg': 11.19}
# {'description': 'Esselunga, suino nodini (bistecche nel filetto) 2 pezzi', 'category': 'carne', 'price': 6.79, 'qty': '1 kg', 'price_per_kg': 6.79}
# {'description': 'Esselunga, suino cotoletta impanata', 'category': 'carne', 'price': 8.79, 'qty': '1 kg', 'price_per_kg': 8.79}
# {'description': 'Esselunga, suino pancetta', 'category': 'carne', 'price': 4.99, 'qty': '1 kg', 'price_per_kg': 4.99}
# {'description': 'Esselunga, coniglio fegato', 'category': 'carne', 'price': 4.09, 'qty': '1 kg', 'price_per_kg': 4.09}
# {'description': 'Esselunga, suino italiano salsiccia arrotolata', 'category': 'carne', 'price': 8.29, 'qty': '1 kg', 'price_per_kg': 8.29}
# {'description': 'Esselunga, suino filetto al pepe verde', 'category': 'carne', 'price': 14.99, 'qty': '1 kg', 'price_per_kg': 10.49}
# {'description': 'Esselunga, coniglio intero', 'category': 'carne', 'price': 8.49, 'qty': '1 kg', 'price_per_kg': 8.49}
# {'description': 'Esselunga, suino puntine (rosticciana)', 'category': 'carne', 'price': 6.19, 'qty': '1 kg', 'price_per_kg': 6.19}
# {'description': 'Esselunga, suino italiano salamella per griglia', 'category': 'carne', 'price': 9.69, 'qty': '1 kg', 'price_per_kg': 9.69}
# {'description': 'Esselunga Naturama, scottona fettine sottili confezione risparmio', 'category': 'carne', 'price': 21.5, 'qty': '1 kg', 'price_per_kg': 17.2}
# {'description': 'Esselunga Naturama, scottona entrecote per tagliata', 'category': 'carne', 'price': 22.12, 'qty': '1 kg', 'price_per_kg': 17.69}
# {'description': 'Esselunga Naturama, scottona tagliata con salvia e rosmarino', 'category': 'carne', 'price': 21.6, 'qty': '1 kg', 'price_per_kg': 21.6}
# {'description': 'Esselunga Naturama, scottona fiorentina', 'category': 'carne', 'price': 19.89, 'qty': '1 kg', 'price_per_kg': 19.89}
# {'description': 'Esselunga Naturama, faraona in parti allevata senza uso di antibiotici', 'category': 'carne', 'price': 8.44, 'qty': '1 kg', 'price_per_kg': 6.75}
# {'description': 'Esselunga, vitello italiano fettine sottili', 'category': 'carne', 'price': 23.5, 'qty': '1 kg', 'price_per_kg': 23.5}
# {'description': 'Esselunga, bovino adulto hamburger 4 pezzi confezione risparmio', 'category': 'carne', 'price': 7.99, 'qty': '1 kg', 'price_per_kg': 7.99}
# {'description': 'Esselunga, scottona di razza piemontese fettine sottili', 'category': 'carne', 'price': 24.37, 'qty': '1 kg', 'price_per_kg': 19.49}
# {'description': 'Esselunga, suino coppa (scamerita disossata) a fette aromatizzate alle erbe', 'category': 'carne', 'price': 8.99, 'qty': '1 kg', 'price_per_kg': 6.29}
# {'description': 'Esselunga, suino salamelle senza pelle 500 g', 'category': 'carne', 'price': 3.99, 'qty': '500 g', 'price_per_kg': 7.98}
# {'description': 'Esselunga Naturama, pollo in parti allevato senza uso di antibiotici', 'category': 'carne', 'price': 5.35, 'qty': '1 kg', 'price_per_kg': 5.35}
# {'description': 'Esselunga Naturama, scottona fettine sottili con formaggio e rucola', 'category': 'carne', 'price': 22.85, 'qty': '1 kg', 'price_per_kg': 15.99}
# {'description': 'Esselunga, vitello italiano biancostato (lesso )', 'category': 'carne', 'price': 8.74, 'qty': '1 kg', 'price_per_kg': 6.99}
# {'description': 'Esselunga Naturama, faraona busto', 'category': 'carne', 'price': 7.29, 'qty': '1 kg', 'price_per_kg': 7.29}
# {'description': "Esselunga, scottona di razza piemontese roast beef (lombata senz'osso) a fette", 'category': 'carne', 'price': 23.99, 'qty': '1 kg', 'price_per_kg': 23.99}
# {'description': 'Esselunga, vitello italiano trita (macinata) scelta', 'category': 'carne', 'price': 11.29, 'qty': '1 kg', 'price_per_kg': 7.9}
# {'description': 'Esselunga, suino arrosto coppa (scamerita)', 'category': 'carne', 'price': 8.79, 'qty': '1 kg', 'price_per_kg': 8.79}
# {'description': 'Esselunga, scottona di razza piemonte trita (macinata) scelta', 'category': 'carne', 'price': 12.99, 'qty': '1 kg', 'price_per_kg': 12.99}
# {'description': 'Esselunga, agnello coscia anteriore', 'category': 'carne', 'price': 12.89, 'qty': '1 kg', 'price_per_kg': 12.89}
# {'description': 'Esselunga, vitello italiano fesa a fettine 3 pezzi', 'category': 'carne', 'price': 20.99, 'qty': '1 kg', 'price_per_kg': 20.99}
# {'description': 'Esselunga, pollo rolatine con prosciutto cotto', 'category': 'carne', 'price': 13.74, 'qty': '1 kg', 'price_per_kg': 10.99}
# {'description': 'Esselunga, suino italiano salsiccia per griglia', 'category': 'carne', 'price': 8.39, 'qty': '1 kg', 'price_per_kg': 8.39}
# {'description': 'EsselungaNaturama, filetto a fette', 'category': 'carne', 'price': 32.4, 'qty': '1 kg', 'price_per_kg': 32.4}
# {'description': 'Esselunga, vitello italiano reale con osso', 'category': 'carne', 'price': 12.89, 'qty': '1 kg', 'price_per_kg': 12.89}
# {'description': 'Esselunga Naturama, scottona costata', 'category': 'carne', 'price': 18.99, 'qty': '1 kg', 'price_per_kg': 18.99}
# {'description': 'Esselunga, vitello italiano magatello (girello)', 'category': 'carne', 'price': 22.42, 'qty': '1 kg', 'price_per_kg': 15.69}
# {'description': 'Esselunga, bovino adulto polpa trita (macinata magra ) scelta confezione risparmio', 'category': 'carne', 'price': 14.17, 'qty': '1 kg', 'price_per_kg': 8.5}
# {'description': 'Esselunga, vitello italiano svizzere 4 pezzi confezione risparmio', 'category': 'carne', 'price': 12, 'qty': '1 kg', 'price_per_kg': 7.2}
# {'description': 'Esselunga, scottona rotolini tricolore', 'category': 'carne', 'price': 23.99, 'qty': '1 kg', 'price_per_kg': 23.99}
# {'description': 'Esselunga, vitello rognone', 'category': 'carne', 'price': 11.99, 'qty': '1 kg', 'price_per_kg': 11.99}
# {'description': 'Esselunga Naturama, scottona roast-beef (lombata disossata)', 'category': 'carne', 'price': 22.8, 'qty': '1 kg', 'price_per_kg': 22.8}
# {'description': 'Esselunga naturama, scottona noce', 'category': 'carne', 'price': 17.2, 'qty': '1 kg', 'price_per_kg': 17.2}
# {'description': 'Esselunga, pollo straccetti alla provenzale', 'category': 'carne', 'price': 17.87, 'qty': '1 kg', 'price_per_kg': 17.87}
# {'description': 'Esselunga, suino coppa (scamerita disossata) a fette aromatizzate alla paprika', 'category': 'carne', 'price': 8.99, 'qty': '1 kg', 'price_per_kg': 8.99}
# {'description': 'Esselunga, vitello tagliata con salsa e rosmarino', 'category': 'carne', 'price': 23.28, 'qty': '1 kg', 'price_per_kg': 16.29}
# {'description': 'Esselunga, pollo sovracosce', 'category': 'carne', 'price': 11.99, 'qty': '1 kg', 'price_per_kg': 11.99}
# {'description': 'Esselunga Naturama, suino paillard 200 g', 'category': 'carne', 'price': 2.49, 'qty': '200 g', 'price_per_kg': 12.45}
# {'description': 'Esselunga, bovino adulto filetto a fette', 'category': 'carne', 'price': 30.4, 'qty': '1 kg', 'price_per_kg': 30.4}
# {'description': 'Esselunga, scottona di razza piemonte polpa trita (macinata di magro) confezione risparmio', 'category': 'carne', 'price': 17.99, 'qty': '1 kg', 'price_per_kg': 14.39}
# {'description': 'Esselunga, vitello italiano nodini (bistecche nel filetto) 2 pezzi', 'category': 'carne', 'price': 19.99, 'qty': '1 kg', 'price_per_kg': 13.99}
# {'description': 'Esselunga, anatra a busto', 'category': 'carne', 'price': 8.39, 'qty': '1 kg', 'price_per_kg': 8.39}
# {'description': 'Esselunga Naturama, suino pancetta a fette 300 g', 'category': 'carne', 'price': 2.87, 'qty': '300 g', 'price_per_kg': 7.64}
# {'description': 'Esselunga, vitello italiano cotolette (bistecche nella costola) 2 pezzi', 'category': 'carne', 'price': 18.99, 'qty': '1 kg', 'price_per_kg': 13.29}
# {'description': 'Esselunga Naturama, suino trita 300 g', 'category': 'carne', 'price': 2.79, 'qty': '300 g', 'price_per_kg': 9.31}
# {'description': 'Esselunga, scottona di razza piemontese filetto a fette', 'category': 'carne', 'price': 33.99, 'qty': '1 kg', 'price_per_kg': 33.99}
# {'description': 'Esselunga, suino arista disossata', 'category': 'carne', 'price': 11.99, 'qty': '1 kg', 'price_per_kg': 11.99}
# {'description': 'Esselunga, agnello cotolette con rosmarino', 'category': 'carne', 'price': 20.99, 'qty': '1 kg', 'price_per_kg': 14.69}
# {'description': 'Esselunga, bovino adulto filetto intero', 'category': 'carne', 'price': 27.9, 'qty': '1 kg', 'price_per_kg': 27.9}
# {'description': 'Esselunga, scottona di razza piemontese biancostato scelto 2 pezzi', 'category': 'carne', 'price': 10.42, 'qty': '1 kg', 'price_per_kg': 7.29}
# {'description': 'Esselunga, vitello italiano noce (rosetta)', 'category': 'carne', 'price': 20.86, 'qty': '1 kg', 'price_per_kg': 14.6}
# {'description': 'Esselunga Naturama, scottona scamone (pezza)', 'category': 'carne', 'price': 19.8, 'qty': '1 kg', 'price_per_kg': 19.8}
# {'description': 'Esselunga Naturama, suino salsiccia 250 g', 'category': 'carne', 'price': 2.24, 'qty': '250 g', 'price_per_kg': 7.16}
# {'description': 'Esselunga, scottona di razza piemontese fettine scelte', 'category': 'carne', 'price': 21.99, 'qty': '1 kg', 'price_per_kg': 21.99}
# {'description': 'Esselunga Naturama, scottona fettine confezione risparmio', 'category': 'carne', 'price': 17.14, 'qty': '1 kg', 'price_per_kg': 11.99}
# {'description': 'Esselunga Naturama, scottona bocconcini', 'category': 'carne', 'price': 16, 'qty': '1 kg', 'price_per_kg': 12.8}
# {'description': 'Esselunga, scottona di razza piemonte polpa trita (macinata di magro)', 'category': 'carne', 'price': 17.99, 'qty': '1 kg', 'price_per_kg': 17.99}
# {'description': 'Esselunga, scottona di razza piemontese fettine per tagliata', 'category': 'carne', 'price': 24.49, 'qty': '1 kg', 'price_per_kg': 24.49}
# {'description': 'Esselunga Naturama, suino hamburger 2 pezzi 200 g', 'category': 'carne', 'price': 1.99, 'qty': '200 g', 'price_per_kg': 6.95}
# {'description': 'Esselunga Naturama, scottona polpa trita confezione risparmio', 'category': 'carne', 'price': 15.2, 'qty': '1 kg', 'price_per_kg': 15.2}
# {'description': 'Esselunga, vitello italiano svizzere 2 pezzi', 'category': 'carne', 'price': 12.7, 'qty': '1 kg', 'price_per_kg': 12.7}
# {'description': 'Esselunga, vitello italiano arrosto di codino (bicchiere) a fette', 'category': 'carne', 'price': 24.28, 'qty': '1 kg', 'price_per_kg': 16.99}
# {'description': 'Esselunga, vitello italiano punta a fette', 'category': 'carne', 'price': 9, 'qty': '1 kg', 'price_per_kg': 7.2}
# {'description': 'Esselunga, vitello straccetti salvia e rosmarino', 'category': 'carne', 'price': 18.62, 'qty': '1 kg', 'price_per_kg': 14.89}
# {'description': 'Esselunga Naturama, scottona fettine sottili', 'category': 'carne', 'price': 21.89, 'qty': '1 kg', 'price_per_kg': 21.89}
# {'description': 'Esselunga, vitello italiano spianaccino (cimalino)', 'category': 'carne', 'price': 19.99, 'qty': '1 kg', 'price_per_kg': 13.99}
# {'description': 'Esselunga, scottona di razza piemontese maxi hamburger', 'category': 'carne', 'price': 15.99, 'qty': '1 kg', 'price_per_kg': 15.99}
# {'description': 'Esselunga, vitello italiano pesce (campanello)', 'category': 'carne', 'price': 18.57, 'qty': '1 kg', 'price_per_kg': 12.99}
# {'description': 'Esselunga Naturama, scottona pesce (campanello)', 'category': 'carne', 'price': 14.28, 'qty': '1 kg', 'price_per_kg': 9.99}
# {'description': 'Esselunga, scottona di razza piemontese bistecche di scamone (bicchiere)', 'category': 'carne', 'price': 22.49, 'qty': '1 kg', 'price_per_kg': 22.49}
# {'description': 'Esselunga, vitello polpettone speck e formaggio', 'category': 'carne', 'price': 19.99, 'qty': '1 kg', 'price_per_kg': 19.99}
# {'description': 'Esselunga, tacchino arrosto di fesa', 'category': 'carne', 'price': 11.99, 'qty': '1 kg', 'price_per_kg': 9.59}
# {'description': "Esselunga, vitello italiano punta d'anca (scannello)", 'category': 'carne', 'price': 20.86, 'qty': '1 kg', 'price_per_kg': 14.6}
# {'description': 'Esselunga, suino grigliata mista', 'category': 'carne', 'price': 9.7, 'qty': '1 kg', 'price_per_kg': 6.79}
# {'description': 'Esselunga Naturama, scottona scamone (pezza) a fette', 'category': 'carne', 'price': 21.69, 'qty': '1 kg', 'price_per_kg': 21.69}
# {'description': 'Esselunga, pollo sovracosce impanate', 'category': 'carne', 'price': 14.28, 'qty': '1 kg', 'price_per_kg': 9.99}
# {'description': 'Esselunga, suino italiano tris di salsicce', 'category': 'carne', 'price': 8.99, 'qty': '1 kg', 'price_per_kg': 6.29}
# {'description': 'Esselunga, vitello italiano spezzatino scelto', 'category': 'carne', 'price': 14.28, 'qty': '1 kg', 'price_per_kg': 9.99}
# {'description': 'Esselunga, scottona di razza piemontese fettine', 'category': 'carne', 'price': 20.99, 'qty': '1 kg', 'price_per_kg': 20.99}
# {'description': 'Esselunga, vitello italiano maxi svizzera sottile', 'category': 'carne', 'price': 14.89, 'qty': '1 kg', 'price_per_kg': 14.89}
# {'description': 'Esselunga, vitello italiano filetto', 'category': 'carne', 'price': 28.59, 'qty': '1 kg', 'price_per_kg': 28.59}
# {'description': 'Esselunga, vitello arrosto scelto', 'category': 'carne', 'price': 17.72, 'qty': '1 kg', 'price_per_kg': 12.4}
# {'description': 'Esselunga, lonza (arista) a fette impanata', 'category': 'carne', 'price': 15.99, 'qty': '1 kg', 'price_per_kg': 11.19}
# {'description': 'Esselunga, vitello italiano ossobuchi anteriori 2 pezzi', 'category': 'carne', 'price': 13.43, 'qty': '1 kg', 'price_per_kg': 9.4}
# {'description': 'Esselunga, bovino adulto scamone (bicchiere)', 'category': 'carne', 'price': 17.99, 'qty': '1 kg', 'price_per_kg': 17.99}
# {'description': 'Esselunga, suino salsicce in bellavista', 'category': 'carne', 'price': 9.89, 'qty': '1 kg', 'price_per_kg': 9.89}
# {'description': 'Esselunga, vitello italiano mini svizzere di fesa 8 pezzi', 'category': 'carne', 'price': 15.43, 'qty': '1 kg', 'price_per_kg': 10.8}
# {'description': 'Esselunga, scottona di razza piemontese spezzatino', 'category': 'carne', 'price': 13.99, 'qty': '1 kg', 'price_per_kg': 9.79}
# {'description': 'Esselunga Naturama, scottona fettine per tagliata', 'category': 'carne', 'price': 21.6, 'qty': '1 kg', 'price_per_kg': 21.6}
# {'description': 'Esselunga, vitello italiano arrosto di codino (bicchiere)', 'category': 'carne', 'price': 22.42, 'qty': '1 kg', 'price_per_kg': 15.69}
# {'description': 'Esselunga, pollo petti impanati', 'category': 'carne', 'price': 17.85, 'qty': '1 kg', 'price_per_kg': 12.49}
# {'description': 'Esselunga, scottona di razza piemontese scaloppe (braciole)', 'category': 'carne', 'price': 16.28, 'qty': '1 kg', 'price_per_kg': 11.39}
# {'description': 'Esselunga, scottona piemontese tagliata di scamone', 'category': 'carne', 'price': 23.99, 'qty': '1 kg', 'price_per_kg': 19.19}
# {'description': 'Esselunga, vitello italiano filetto a fette', 'category': 'carne', 'price': 28.99, 'qty': '1 kg', 'price_per_kg': 28.99}
# {'description': 'Esselunga, vitello italiano sottofesa (sottonoce)', 'category': 'carne', 'price': 20.86, 'qty': '1 kg', 'price_per_kg': 14.6}
# {'description': 'Esselunga, vitello carrè disossato', 'category': 'carne', 'price': 27, 'qty': '1 kg', 'price_per_kg': 18.9}
# {'description': 'Esselunga, vitello milanese impanata', 'category': 'carne', 'price': 23.5, 'qty': '1 kg', 'price_per_kg': 18.8}
# {'description': 'Esselunga, vitello italiano ossobuchi posteriori', 'category': 'carne', 'price': 14.87, 'qty': '1 kg', 'price_per_kg': 10.4}
# {'description': 'Esselunga, pollo fettine sottili impanate', 'category': 'carne', 'price': 18.72, 'qty': '1 kg', 'price_per_kg': 18.72}
# {'description': 'Esselunga, scottona piemontese tagliata di roastbeef', 'category': 'carne', 'price': 24.99, 'qty': '1 kg', 'price_per_kg': 24.99}
# {'description': 'Esselunga, vitello italiano fettine per tagliata', 'category': 'carne', 'price': 22.4, 'qty': '1 kg', 'price_per_kg': 22.4}
# {'description': 'Esselunga, tacchino fesa intera', 'category': 'carne', 'price': 6.79, 'qty': '1 kg', 'price_per_kg': 6.79}
# {'description': 'Esselunga Naturama, scottona codone', 'category': 'carne', 'price': 16.99, 'qty': '1 kg', 'price_per_kg': 16.99}
# {'description': 'Esselunga, tacchino arrosto', 'category': 'carne', 'price': 7.74, 'qty': '1 kg', 'price_per_kg': 7.74}
# {'description': 'Esselunga, scottona piemontese entrecoteper tagliata', 'category': 'carne', 'price': 24.99, 'qty': '1 kg', 'price_per_kg': 19.99}
# {'description': 'Esselunga, vitello rollè salvia e rosmarino', 'category': 'carne', 'price': 12.85, 'qty': '1 kg', 'price_per_kg': 8.99}
# {'description': 'Esselunga, anatra a metà', 'category': 'carne', 'price': 9.59, 'qty': '1 kg', 'price_per_kg': 9.59}
# {'description': 'Esselunga, vitello carrè per tagliata', 'category': 'carne', 'price': 28, 'qty': '1 kg', 'price_per_kg': 19.6}
# {'description': 'Esselunga, vitello fesa impanata', 'category': 'carne', 'price': 23.6, 'qty': '1 kg', 'price_per_kg': 23.6}
# {'description': 'Esselunga, tacchino fesa impanata', 'category': 'carne', 'price': 18.72, 'qty': '1 kg', 'price_per_kg': 18.72}
# {'description': 'Esselunga, scottona di razza piemontese polpa di spalla', 'category': 'carne', 'price': 14.99, 'qty': '1 kg', 'price_per_kg': 10.49}
# {'description': 'Esselunga, scottona di razza piemontese punta di petto', 'category': 'carne', 'price': 10.42, 'qty': '1 kg', 'price_per_kg': 7.29}
# {'description': 'Esselunga, pollo bocconcini di petto impanati', 'category': 'carne', 'price': 17.85, 'qty': '1 kg', 'price_per_kg': 17.85}
# {'description': 'Esselunga, scottona piemontese polpa per tartare', 'category': 'carne', 'price': 22.99, 'qty': '1 kg', 'price_per_kg': 18.39}
# {'description': 'Esselunga, vitello italiano cappello di prete (sorra)', 'category': 'carne', 'price': 18.2, 'qty': '1 kg', 'price_per_kg': 18.2}
# {'description': 'Esselunga, vitello italiano bocconcini', 'category': 'carne', 'price': 19.15, 'qty': '1 kg', 'price_per_kg': 13.4}
# {'description': 'Esselunga, vitello italiano braciola (falata con osso a fette)', 'category': 'carne', 'price': 13.49, 'qty': '1 kg', 'price_per_kg': 13.49}
# {'description': 'Esselunga Naturama, scottona fettine scelte confezione risparmio', 'category': 'carne', 'price': 18.2, 'qty': '1 kg', 'price_per_kg': 18.2}
# {'description': 'Esselunga, pollo saltimbocca', 'category': 'carne', 'price': 17.85, 'qty': '1 kg', 'price_per_kg': 17.85}
# {'description': 'Esselunga Naturama, scottona scaloppe', 'category': 'carne', 'price': 15.6, 'qty': '1 kg', 'price_per_kg': 15.6}
# {'description': 'Esselunga, suino involtini', 'category': 'carne', 'price': 15.99, 'qty': '1 kg', 'price_per_kg': 11.19}
# {'description': 'Esselunga, scottona di razza piemontese polpa reale (magro di polso)', 'category': 'carne', 'price': 14.99, 'qty': '1 kg', 'price_per_kg': 10.49}
# {'description': 'Esselunga, tris per grigliata', 'category': 'carne', 'price': 11.69, 'qty': '1 kg', 'price_per_kg': 11.69}
# {'description': 'Esselunga, vitello italiano arrosto di fesa', 'category': 'carne', 'price': 14.89, 'qty': '1 kg', 'price_per_kg': 14.89}
# {'description': 'Esselunga, vitello italiano fusello (girello di spalla)', 'category': 'carne', 'price': 17.89, 'qty': '1 kg', 'price_per_kg': 17.89}
# {'description': 'Esselunga Naturama, fettine scelte', 'category': 'carne', 'price': 18.8, 'qty': '1 kg', 'price_per_kg': 18.8}
# {'description': 'Esselunga, scottona di razza piemontese fiorentina', 'category': 'carne', 'price': 22.99, 'qty': '1 kg', 'price_per_kg': 22.99}
# {'description': 'Esselunga, tacchino fusi senza pelle 2 pezzi', 'category': 'carne', 'price': 3.4, 'qty': '1 kg', 'price_per_kg': 3.4}
# {'description': 'Esselunga, vitello rotolini tirolesi', 'category': 'carne', 'price': 19.99, 'qty': '1 kg', 'price_per_kg': 19.99}
# {'description': 'Esselunga, vitello italiano spezzatino', 'category': 'carne', 'price': 12.99, 'qty': '1 kg', 'price_per_kg': 12.99}
# {'description': 'Esselunga, vitello piccata di filetto', 'category': 'carne', 'price': 30.99, 'qty': '1 kg', 'price_per_kg': 30.99}
# {'description': 'Esselunga, scottona di razza piemontese bocconcini di polpa', 'category': 'carne', 'price': 18.99, 'qty': '1 kg', 'price_per_kg': 13.29}
# {'description': 'Esselunga, scottona di razza piemonte straccetti', 'category': 'carne', 'price': 16.19, 'qty': '1 kg', 'price_per_kg': 16.19}
# {'description': 'Esselunga, scottona di razza piemontese ossobuchi', 'category': 'carne', 'price': 10.99, 'qty': '1 kg', 'price_per_kg': 7.69}
# {'description': 'Esselunga Naturama, scottona sottofesa', 'category': 'carne', 'price': 16.99, 'qty': '1 kg', 'price_per_kg': 16.99}
# {'description': 'Esselunga, bovino adulto scamone (bicchiere) a fette', 'category': 'carne', 'price': 18.99, 'qty': '1 kg', 'price_per_kg': 18.99}
# {'description': 'Esselunga Naturama, scottona magatello (girello)', 'category': 'carne', 'price': 17.49, 'qty': '1 kg', 'price_per_kg': 17.49}
# {'description': 'Esselunga, suino arista con osso', 'category': 'carne', 'price': 8.99, 'qty': '1 kg', 'price_per_kg': 8.99}
# {'description': 'Esselunga, tacchino arrosto ripieno a brasato', 'category': 'carne', 'price': 15.37, 'qty': '1 kg', 'price_per_kg': 15.37}
# {'description': 'Esselunga, vitello italiano fettine di fesa per scaloppe (campanello)', 'category': 'carne', 'price': 19.29, 'qty': '1 kg', 'price_per_kg': 19.29}
# {'description': 'Esselunga, suino grigliata', 'category': 'carne', 'price': 9.39, 'qty': '1 kg', 'price_per_kg': 9.39}
# {'description': 'Esselunga, bovino/suino polpettone farcito', 'category': 'carne', 'price': 13.72, 'qty': '1 kg', 'price_per_kg': 9.6}
# {'description': 'Esselunga, bovino adulto entrecote', 'category': 'carne', 'price': 18.8, 'qty': '1 kg', 'price_per_kg': 18.8}
# {'description': 'Esselunga, scottona di razza piemontese entrecote', 'category': 'carne', 'price': 23.49, 'qty': '1 kg', 'price_per_kg': 23.49}
# {'description': "Esselunga Naturama, scottona punta d'anca", 'category': 'carne', 'price': 16.99, 'qty': '1 kg', 'price_per_kg': 16.99}
# {'description': 'Esselunga Naturama, scottona fiorentina alta', 'category': 'carne', 'price': 19.99, 'qty': '1 kg', 'price_per_kg': 19.99}
# {'description': 'Esselunga, bovino adulto roast beef (lombata disossata) a fette confezione risparmio', 'category': 'carne', 'price': 19.43, 'qty': '1 kg', 'price_per_kg': 13.6}
# {'description': 'Esselunga Naturama, scottona entrecote', 'category': 'carne', 'price': 21.99, 'qty': '1 kg', 'price_per_kg': 21.99}
# {'description': 'Esselunga, vitello rognone a fette', 'category': 'carne', 'price': 13.99, 'qty': '1 kg', 'price_per_kg': 13.99}
# {'description': 'Esselunga, vitello saltimbocca', 'category': 'carne', 'price': 23.69, 'qty': '1 kg', 'price_per_kg': 23.69}
# {'description': 'Esselunga Naturama, scottona scamone (bicchiere) al lardo e alloro', 'category': 'carne', 'price': 21.49, 'qty': '1 kg', 'price_per_kg': 21.49}
# {'description': 'Esselunga, vitello italiano arrosto di spalla', 'category': 'carne', 'price': 14.4, 'qty': '1 kg', 'price_per_kg': 14.4}
# {'description': 'Esselunga, scottona di razza piemontese pesce (campanello)', 'category': 'carne', 'price': 15.99, 'qty': '1 kg', 'price_per_kg': 11.19}
# {'description': 'Esselunga, scottona piemontese tramezzino', 'category': 'carne', 'price': 18.79, 'qty': '1 kg', 'price_per_kg': 18.79}
# {'description': 'Esselunga, agnello cotolette impanate', 'category': 'carne', 'price': 20.99, 'qty': '1 kg', 'price_per_kg': 20.99}
# {'description': 'Esselunga, vitello italiano arrosto di reale', 'category': 'carne', 'price': 14.4, 'qty': '1 kg', 'price_per_kg': 14.4}
# {'description': 'Esselunga, pollo straccetti alla salsa verde', 'category': 'carne', 'price': 17.84, 'qty': '1 kg', 'price_per_kg': 17.84}
# {'description': 'Esselunga, scottona di razza piemontese fusello (girello di spalla)', 'category': 'carne', 'price': 15.99, 'qty': '1 kg', 'price_per_kg': 11.19}
# {'description': 'Esselunga, vitello italiano carrè disossato a fette 3 pezzi', 'category': 'carne', 'price': 27.4, 'qty': '1 kg', 'price_per_kg': 27.4}
# {'description': 'Esselunga, scottona di razza piemontese spinacino (cimalino)', 'category': 'carne', 'price': 15.29, 'qty': '1 kg', 'price_per_kg': 15.29}
# {'description': 'Esselunga, scottona piemontese girolle tricolore', 'category': 'carne', 'price': 25.99, 'qty': '1 kg', 'price_per_kg': 20.79}
# {'description': 'Esselunga, pollo straccetti marinati in salsa al pepe nero e rosa', 'category': 'carne', 'price': 17.87, 'qty': '1 kg', 'price_per_kg': 17.87}
# {'description': 'Esselunga, scottona di razza piemontese codone (lucertolo)', 'category': 'carne', 'price': 17.39, 'qty': '1 kg', 'price_per_kg': 17.39}
# {'description': 'Esselunga, suino filetto marinato in salsa al pepe rosa e nero', 'category': 'carne', 'price': 15.69, 'qty': '1 kg', 'price_per_kg': 15.69}
# {'description': 'Esselunga, vitello italiano straccetti', 'category': 'carne', 'price': 18.6, 'qty': '1 kg', 'price_per_kg': 18.6}
# {'description': 'Esselunga, agnello carrè in bellavista', 'category': 'carne', 'price': 28.59, 'qty': '1 kg', 'price_per_kg': 28.59}
# {'description': 'Esselunga, vitello stinco', 'category': 'carne', 'price': 13.99, 'qty': '1 kg', 'price_per_kg': 13.99}
# {'description': 'Esselunga, scottona di razza piemontese noce (rosetta)', 'category': 'carne', 'price': 18.99, 'qty': '1 kg', 'price_per_kg': 18.99}
# {'description': 'Esselunga, vitello italiano fesa di spalla (sodo)', 'category': 'carne', 'price': 17.89, 'qty': '1 kg', 'price_per_kg': 17.89}
# {'description': 'Esselunga, suino Tournedos', 'category': 'carne', 'price': 14.99, 'qty': '1 kg', 'price_per_kg': 14.99}
# {'description': "Esselunga, anatra petto all'arancia", 'category': 'carne', 'price': 16.99, 'qty': '1 kg', 'price_per_kg': 16.99}
# {'description': 'Esselunga Naturama, scottona valdostane', 'category': 'carne', 'price': 21.42, 'qty': '1 kg', 'price_per_kg': 14.99}
# {'description': 'Esselunga, scottona di razza piemonte mini hamburger scelti 6 pezzi', 'category': 'carne', 'price': 17.99, 'qty': '1 kg', 'price_per_kg': 12.59}
# {'description': 'Esselunga, pollo fusi alla salsa verde', 'category': 'carne', 'price': 12.42, 'qty': '1 kg', 'price_per_kg': 12.42}
# {'description': 'Esselunga, bovino adulto bicchiere al pepe verde', 'category': 'carne', 'price': 19.99, 'qty': '1 kg', 'price_per_kg': 13.99}
# {'description': 'Esselunga, scottona di razza piemontese scamone (bicchiere)', 'category': 'carne', 'price': 19.99, 'qty': '1 kg', 'price_per_kg': 19.99}
# {'description': 'Esselunga, vitello filetto al pepe rosa', 'category': 'carne', 'price': 29.28, 'qty': '1 kg', 'price_per_kg': 20.49}
# {'description': "Esselunga, scottona di razza piemontese roast beef (lombata senz'osso)", 'category': 'carne', 'price': 23.99, 'qty': '1 kg', 'price_per_kg': 23.99}
# {'description': 'Esselunga, agnello per griglia', 'category': 'carne', 'price': 13.56, 'qty': '1 kg', 'price_per_kg': 9.49}
# {'description': 'Esselunga, pollo rollè', 'category': 'carne', 'price': 8.8, 'qty': '1 kg', 'price_per_kg': 8.8}
# {'description': 'Esselunga, bovino adulto roast beef (lombata disossata)', 'category': 'carne', 'price': 18.19, 'qty': '1 kg', 'price_per_kg': 18.19}
# {'description': 'Esselunga, vitello italiano cotolette alla milanese 2 pezzi', 'category': 'carne', 'price': 19.99, 'qty': '1 kg', 'price_per_kg': 19.99}
# {'description': 'Esselunga, scottona di razza piemonte magatello (girello)', 'category': 'carne', 'price': 20.19, 'qty': '1 kg', 'price_per_kg': 20.19}
# {'description': 'Esselunga Naturama, scottona ossobuchi', 'category': 'carne', 'price': 9.99, 'qty': '1 kg', 'price_per_kg': 6.99}
# {'description': 'Esselunga, vitello involtini', 'category': 'carne', 'price': 20.4, 'qty': '1 kg', 'price_per_kg': 20.4}
# {'description': 'Esselunga, agnello carrè disossato', 'category': 'carne', 'price': 24.99, 'qty': '1 kg', 'price_per_kg': 24.99}
# {'description': 'Esselunga, scottona piemontese girolle con erba cipollina', 'category': 'carne', 'price': 25.99, 'qty': '1 kg', 'price_per_kg': 25.99}
# {'description': 'Esselunga, agnello anteriore', 'category': 'carne', 'price': 12.85, 'qty': '1 kg', 'price_per_kg': 8.99}
# {'description': 'Esselunga, misto per grigliata', 'category': 'carne', 'price': 8.9, 'qty': '1 kg', 'price_per_kg': 8.9}
# {'description': 'Esselunga, scottona piemontese tris di bocconcini', 'category': 'carne', 'price': 18.49, 'qty': '1 kg', 'price_per_kg': 18.49}
# {'description': 'Esselunga Naturama, scottona filetto con lardo e alloro', 'category': 'carne', 'price': 33.25, 'qty': '1 kg', 'price_per_kg': 33.25}
# {'description': 'Esselunga, scottona piemontese tris per Fajitas', 'category': 'carne', 'price': 16.99, 'qty': '1 kg', 'price_per_kg': 16.99}
# {'description': 'Esselunga, scottona piemontese roast-beef', 'category': 'carne', 'price': 23.29, 'qty': '1 kg', 'price_per_kg': 23.29}
# {'description': 'Esselunga, vitello italiano rollè', 'category': 'carne', 'price': 11.99, 'qty': '1 kg', 'price_per_kg': 11.99}
# {'description': 'Esselunga, vitello carrè', 'category': 'carne', 'price': 25.99, 'qty': '1 kg', 'price_per_kg': 25.99}
# {'description': 'Esselunga, Agnello posteriore (cosciotto)', 'category': 'carne', 'price': 14.28, 'qty': '1 kg', 'price_per_kg': 9.99}
# {'description': 'Esselunga fetta per polpettone (tasca) di scottona piemontese', 'category': 'carne', 'price': 15.99, 'qty': '1 kg', 'price_per_kg': 15.99}
# {'description': 'Esselunga, agnello collo e costine', 'category': 'carne', 'price': 9.7, 'qty': '1 kg', 'price_per_kg': 6.79}
# {'description': 'Esselunga, vitello italiano fetta per polpettone', 'category': 'carne', 'price': 19.99, 'qty': '1 kg', 'price_per_kg': 19.99}
# {'description': 'Esselunga, agnello carrè', 'category': 'carne', 'price': 14.28, 'qty': '1 kg', 'price_per_kg': 9.99}
# {'description': 'Esselunga, vitello arrosto ripieno al brasato', 'category': 'carne', 'price': 19.99, 'qty': '1 kg', 'price_per_kg': 19.99}
# {'description': 'Esselunga, faraona con ripieno al brasato', 'category': 'carne', 'price': 11.99, 'qty': '1 kg', 'price_per_kg': 11.99}
# {'description': 'Esselunga, scottona piemontese girolle al formaggio con sedano e capperi', 'category': 'carne', 'price': 25.99, 'qty': '1 kg', 'price_per_kg': 25.99}
# {'description': "Esselunga, anatra all'arancia", 'category': 'carne', 'price': 13, 'qty': '1 kg', 'price_per_kg': 13.0}
# {'description': 'Esselunga Naturama, scottona spinacino', 'category': 'carne', 'price': 14.28, 'qty': '1 kg', 'price_per_kg': 9.99}
# {'description': 'Esselunga, cappone ripieno al brasato', 'category': 'carne', 'price': 14.99, 'qty': '1 kg', 'price_per_kg': 14.99}
# {'description': 'Aia, Sottilissime petto di pollo', 'category': 'carne', 'price': 14.28, 'qty': '1 kg', 'price_per_kg': 11.42}
# {'description': 'Esselunga,petto a fette di pollo ad alimentazione vegetale', 'category': 'carne', 'price': 10.99, 'qty': '1 kg', 'price_per_kg': 10.99}
# {'description': 'Esselunga Hamburgeria, hamburger di bovino adulto classico 4 pezzi 500 g', 'category': 'carne', 'price': 5.37, 'qty': '500 g', 'price_per_kg': 8.58}
# {'description': 'Aia, Sottilissime di tacchino', 'category': 'carne', 'price': 14.5, 'qty': '1 kg', 'price_per_kg': 11.6}
# {'description': 'Hamburger di tacchino 2 pezzi 200 g', 'category': 'carne', 'price': 1.59, 'qty': '200 g', 'price_per_kg': 7.95}
# {'description': 'Fileni, petto a fette di pollo biologico', 'category': 'carne', 'price': 20.99, 'qty': '1 kg', 'price_per_kg': 16.79}
# {'description': 'Salumificio Trentino Bella, Le Sottili carne salada del trentino 125 g', 'category': 'carne', 'price': 3.74, 'qty': '125 g', 'price_per_kg': 23.92}
# {'description': 'Aia, Sottilissime cotolette panate di filetti di pollo 140 g', 'category': 'carne', 'price': 2.09, 'qty': '140 g', 'price_per_kg': 10.43}
# {'description': 'Vallespluga, galletto', 'category': 'carne', 'price': 7.3, 'qty': '1 kg', 'price_per_kg': 7.3}
# {'description': 'Guidi, fuso e sovracoscia del Pollo della Domenica, allevato senza uso di antibiotici', 'category': 'carne', 'price': 9.1, 'qty': '1 kg', 'price_per_kg': 9.1}
# {'description': 'Fileni, hamburger di pollo biologico 200 g', 'category': 'carne', 'price': 3.9, 'qty': '200 g', 'price_per_kg': 15.6}
# {'description': 'Aia, petto di pollo a fette', 'category': 'carne', 'price': 11.9, 'qty': '1 kg', 'price_per_kg': 11.9}
# {'description': 'Guidi, petto a fette del Pollo della Domenica, allevato senza uso di antibiotici', 'category': 'carne', 'price': 20.39, 'qty': '1 kg', 'price_per_kg': 20.39}
# {'description': 'Aia, tacchino hamburger con rosmarino 2 pezzi 200 g', 'category': 'carne', 'price': 2.7, 'qty': '200 g', 'price_per_kg': 13.5}
# {'description': 'Smart, suino cotolette (bistecche nella costola) confezione risparmio', 'category': 'carne', 'price': 4.99, 'qty': '1 kg', 'price_per_kg': 4.99}
# {'description': 'Esselunga Hamburgeria, bovino adulto hamburger di Scottona Naturama classici 250 g', 'category': 'carne', 'price': 4.3, 'qty': '250 g', 'price_per_kg': 17.2}
# {'description': 'Aia, hamburger di coniglio 215 g', 'category': 'carne', 'price': 4.28, 'qty': '215 g', 'price_per_kg': 19.91}
# {'description': 'Guidi, Pollo della Domenica in parti, allevato senza uso di antibiotici', 'category': 'carne', 'price': 7.75, 'qty': '1 kg', 'price_per_kg': 7.75}
# {'description': 'Esselunga Naturama, scottona polpa scelta con olio al limone', 'category': 'carne', 'price': 21.5, 'qty': '1 kg', 'price_per_kg': 17.2}
# {'description': 'Amadori, I Grandi Classici polpettine 240 g', 'category': 'carne', 'price': 3.59, 'qty': '240 g', 'price_per_kg': 14.96}
# {'description': 'Smart, suino nodini (bistecche nel filetto) confezione risparmio', 'category': 'carne', 'price': 4.99, 'qty': '1 kg', 'price_per_kg': 4.99}
# {'description': 'Guidi,  alette del Pollo della Domenica, allevato senza uso di antibiotici', 'category': 'carne', 'price': 6.99, 'qty': '1 kg', 'price_per_kg': 6.99}
# {'description': 'Esselunga Naturama, scottona polpa scelta con olio alla senape', 'category': 'carne', 'price': 21.5, 'qty': '1 kg', 'price_per_kg': 17.2}
# {'description': 'Nuggets di petto di pollo', 'category': 'carne', 'price': 7.69, 'qty': '1 kg', 'price_per_kg': 7.69}
# {'description': 'Smart petti di pollo', 'category': 'carne', 'price': 6.75, 'qty': '1 kg', 'price_per_kg': 6.75}
# {'description': 'Fiorani, capricci di vitello e suino 300 g', 'category': 'carne', 'price': 2.99, 'qty': '300 g', 'price_per_kg': 9.97}
# {'description': 'Esselunga Hamburgeria, bovino adulto maxi hamburger di Scottona Naturama al gusto barbecue 220 g', 'category': 'carne', 'price': 3.88, 'qty': '220 g', 'price_per_kg': 14.1}
# {'description': 'Smart posteriori di pollo alimentazione vegetale', 'category': 'carne', 'price': 2.49, 'qty': '1 kg', 'price_per_kg': 2.49}
# {'description': 'Aia, Chicken Salad tagliata di petti di pollo 350 g', 'category': 'carne', 'price': 4.99, 'qty': '350 g', 'price_per_kg': 9.98}
# {'description': 'Amadori, macinato fine di tacchino 270 g', 'category': 'carne', 'price': 2.99, 'qty': '270 g', 'price_per_kg': 11.08}
# {'description': 'Aia, croccanti arrosticini di pollo con panatura al rosmarino', 'category': 'carne', 'price': 14.9, 'qty': '1 kg', 'price_per_kg': 14.9}
# {'description': 'Guidi, Pollo della Domenica busto , allevato senza uso di antibiotici', 'category': 'carne', 'price': 6.79, 'qty': '1 kg', 'price_per_kg': 6.79}
# {'description': 'Amadori, tagliata di petto di pollo 400 g', 'category': 'carne', 'price': 3.99, 'qty': '400 g', 'price_per_kg': 9.98}
# {'description': 'Quaglie', 'category': 'carne', 'price': 8.39, 'qty': '1 kg', 'price_per_kg': 8.39}
# {'description': 'Guidi, Gran Galletto griglia', 'category': 'carne', 'price': 7.99, 'qty': '1 kg', 'price_per_kg': 7.99}
# {'description': 'Fileni, fusi di pollo biologico', 'category': 'carne', 'price': 9.99, 'qty': '1 kg', 'price_per_kg': 9.99}
# {'description': 'Guidi, gallo in parti , allevato senza uso di antibiotici', 'category': 'carne', 'price': 8.99, 'qty': '1 kg', 'price_per_kg': 8.99}
# {'description': 'Aia, Spinacina Grancroccante 300 g', 'category': 'carne', 'price': 4.2, 'qty': '300 g', 'price_per_kg': 14.01}
# {'description': 'Aia, La Viennese cotoletta di filetti di pollo impanata 300 g', 'category': 'carne', 'price': 4.45, 'qty': '300 g', 'price_per_kg': 14.84}
# {'description': 'Aia, Spinacine di pollo e tacchino 2 pezzi 220 g', 'category': 'carne', 'price': 2.7, 'qty': '220 g', 'price_per_kg': 8.6}
# {'description': 'Spiedì, Agnello arrosticini 10 pezzi 200 g', 'category': 'carne', 'price': 4.99, 'qty': '200 g', 'price_per_kg': 24.95}
# {'description': 'Fileni, alette di pollo biologico', 'category': 'carne', 'price': 5.89, 'qty': '1 kg', 'price_per_kg': 5.89}
# {'description': 'Aia, Cordon Bleu Classico di tacchino 2 pezzi 245 kg', 'category': 'carne', 'price': 3.7, 'qty': '245 g', 'price_per_kg': 7.56}
# {'description': 'Certified Irish Angus Beef, Striploin Steak 454 g', 'category': 'carne', 'price': 14.99, 'qty': '454 g', 'price_per_kg': 33.02}
# {'description': 'Aia, Chicken Burger hamburger di pollo 200 g', 'category': 'carne', 'price': 2.7, 'qty': '200 g', 'price_per_kg': 8.1}
# {'description': 'Fileni, spezzatino di pollo biologico', 'category': 'carne', 'price': 16.49, 'qty': '1 kg', 'price_per_kg': 16.49}
# {'description': 'Fileni, bocconcini di petto di pollo biologico 220 g', 'category': 'carne', 'price': 3.9, 'qty': '220 g', 'price_per_kg': 17.73}
# {'description': 'Aia, La Milanese cotoletta di pollo 280 g', 'category': 'carne', 'price': 3.5, 'qty': '280 g', 'price_per_kg': 12.5}
# {'description': 'Berti, coniglio fettine scelte', 'category': 'carne', 'price': 20.1, 'qty': '1 kg', 'price_per_kg': 20.1}
# {'description': 'Cotoletta di filetti di pollo impanata 440 g', 'category': 'carne', 'price': 3.7, 'qty': '440 g', 'price_per_kg': 8.41}
# {'description': 'Smart ali di pollo alimentazione vegetale', 'category': 'carne', 'price': 1.95, 'qty': '1 kg', 'price_per_kg': 1.95}
# {'description': 'Aia, tacchino fesa a fette', 'category': 'carne', 'price': 12.4, 'qty': '1 kg', 'price_per_kg': 12.4}
# {'description': 'Delicatesse, bovino adulto pastrami', 'category': 'carne', 'price': 2.8, 'qty': '100 g', 'price_per_kg': 28.0}
# {'description': 'Aia, Durango alette arrosto di pollo 500 g', 'category': 'carne', 'price': 5.5, 'qty': '500 g', 'price_per_kg': 11.0}
# {'description': 'Hamburgeria Esselunga polpette di vitello', 'category': 'carne', 'price': 4.99, 'qty': '300 g', 'price_per_kg': 16.64}
# {'description': "Mericco, Bell'Idea pasta di salame 280 g", 'category': 'carne', 'price': 2.39, 'qty': '280 g', 'price_per_kg': 8.54}
# {'description': 'Ariosto, insaporitore per carni arrosto e ai ferri 100 g', 'category': 'Confezionati alimentari', 'price': 2.89, 'qty': '100 g', 'price_per_kg': 28.9}
# {'description': 'Aia, Valdostana 200 g', 'category': 'carne', 'price': 3.1, 'qty': '200 g', 'price_per_kg': 15.5}
# {'description': 'Carni dal Mondo Filetto Australia a fette', 'category': 'carne', 'price': 55.9, 'qty': '1 kg', 'price_per_kg': 55.9}
# {'description': "Petto d'anatra,", 'category': 'carne', 'price': 18.65, 'qty': '1 kg', 'price_per_kg': 18.65}
# ...
# {'description': 'Star, Il mio Brodo di carne mista 1 l', 'category': 'Confezionati alimentari', 'price': 1.99, 'qty': '1000 ml', 'price_per_kg': 1.99}
# {'description': 'San Carlo, Dixi conf. 6x22 g', 'category': 'Confezionati alimentari', 'price': 1.95, 'qty': '132 g', 'price_per_kg': 8.72}
# {'description': 'Mulino Bianco, Plumcake con gocce di cioccolato 10 pezzi 350 g', 'category': 'Confezionati alimentari', 'price': 2.35, 'qty': '350 g', 'price_per_kg': 6.72}
# {'description': 'Saiwa, Oro classico 375 g', 'category': 'Confezionati alimentari', 'price': 1.86, 'qty': '375 g', 'price_per_kg': 4.96}
# {'description': 'Cirio, La Rustica passata di pomodoro 680 g', 'category': 'Confezionati alimentari', 'price': 1.74, 'qty': '680 g', 'price_per_kg': 2.56}
# {'description': 'Fiorentini, Bio fiocchi di avena 350 g', 'category': 'Confezionati alimentari', 'price': 1.69, 'qty': '350 g', 'price_per_kg': 4.83}
# {'description': 'Mulino Bianco, Tegolino 10 pezzi 350 g', 'category': 'Confezionati alimentari', 'price': 2.43, 'qty': '350 g', 'price_per_kg': 6.95}
# {'description': 'Pringles, paprika 165 g', 'category': 'Confezionati alimentari', 'price': 2.15, 'qty': '165 g', 'price_per_kg': 13.04}
# {'description': 'Galbusera, PiùIntegrali 440 g', 'category': 'Confezionati alimentari', 'price': 2.99, 'qty': '440 g', 'price_per_kg': 6.8}
# {'description': 'Polli, olive nere denocciolate conf. 2x50 g', 'category': 'Confezionati alimentari', 'price': 1.69, 'qty': '100 g', 'price_per_kg': 16.9}
# {'description': "Parmareggio, L'ABC della Merenda frullato 100% frutta gusto pera, grissini, formaggino", 'category': 'latticini_e_formaggi', 'price': 1, 'qty': '165 g', 'price_per_kg': 6.07}
# {'description': 'Barilla, I Pesti alla genovese 170 g', 'category': 'Confezionati alimentari', 'price': 2.19, 'qty': '170 g', 'price_per_kg': 12.89}
# {'description': 'Mutti, Le verdurine salsina di pomodoro e verdurine 140 g', 'category': 'Confezionati alimentari', 'price': 1.07, 'qty': '140 g', 'price_per_kg': 7.65}
# {'description': 'Pan di Stelle, crema 330 g', 'category': 'Confezionati alimentari', 'price': 3.59, 'qty': '330 g', 'price_per_kg': 10.88}
# {'description': 'Mulino Bianco, Settembrini paste frolle con fico 250 g', 'category': 'Confezionati alimentari', 'price': 1.65, 'qty': '250 g', 'price_per_kg': 6.6}
# {'description': 'Gemma di Mare, Gli Integrali sale marino del Mediterraneo grosso 1 kg', 'category': 'Confezionati alimentari', 'price': 0.79, 'qty': '1 kg', 'price_per_kg': 0.79}
# {'description': "Rio Mare, tonno all'olio d'oliva conf. 3x120 g + 1 gratis", 'category': 'Confezionati alimentari', 'price': 6.99, 'qty': '360 g', 'price_per_kg': 19.42}
# {'description': 'Motta, Buondì al cioccolato 6 pezzi 276 g', 'category': 'Confezionati alimentari', 'price': 2.39, 'qty': '276 g', 'price_per_kg': 8.66}
# {'description': 'Mulino Bianco, Abbracci 700 g', 'category': 'Confezionati alimentari', 'price': 3.15, 'qty': '700 g', 'price_per_kg': 4.51}
# {'description': 'Saiwa, Oro Fibrattiva 400 g', 'category': 'Confezionati alimentari', 'price': 1.99, 'qty': '400 g', 'price_per_kg': 3.98}
# {'description': "Bauli, il Croissant all'albicocca 6 pezzi 300 g", 'category': 'Confezionati alimentari', 'price': 2.08, 'qty': '300 g', 'price_per_kg': 6.94}
# {'description': 'Mutti, passata di pomodoro al basilico 700 g', 'category': 'Confezionati alimentari', 'price': 1.85, 'qty': '700 g', 'price_per_kg': 2.65}
# {'description': 'Mulino Bianco, Primizie 700 g', 'category': 'Confezionati alimentari', 'price': 2.99, 'qty': '700 g', 'price_per_kg': 4.28}
# {'description': 'Amica Chips, Eldorada la tradizionale 130 g', 'category': 'Confezionati alimentari', 'price': 1.35, 'qty': '130 g', 'price_per_kg': 10.39}
# {'description': "Mulino Bianco, Cornetti all'albicocca 6 pezzi 300 g", 'category': 'Confezionati alimentari', 'price': 2.27, 'qty': '300 g', 'price_per_kg': 7.57}
# {'description': 'Barilla, Piccolini Mini Penne Rigate pasta di semola di grano duro 500 g', 'category': 'Confezionati alimentari', 'price': 0.79, 'qty': '500 g', 'price_per_kg': 1.58}
# {'description': 'Pavesi, Togo classic latte 120 g', 'category': 'Confezionati alimentari', 'price': 1.59, 'qty': '120 g', 'price_per_kg': 13.26}
# {'description': 'Mulino Bianco, Chicchi di Cioccolato 300 g', 'category': 'Confezionati alimentari', 'price': 1.7, 'qty': '300 g', 'price_per_kg': 5.67}
# {'description': 'Molino Mettone, farina di grano tenero tipo 0 1 kg', 'category': 'Confezionati alimentari', 'price': 0.73, 'qty': '1 kg', 'price_per_kg': 0.73}
# {'description': 'Novi, Fondentenero cioccolato fondente extra 72% senza glutine 100 g', 'category': 'Confezionati alimentari', 'price': 1.49, 'qty': '100 g', 'price_per_kg': 14.9}
# {'description': 'Daygum, Protex Gel alla fragola chewing gum senza glutine senza zucchero conf. 2x60 g', 'category': 'Confezionati alimentari', 'price': 2.49, 'qty': '60 g', 'price_per_kg': 41.6}
# {'description': 'Melchiori, aceto di mele 75 cl', 'category': 'Confezionati alimentari', 'price': 1.99, 'qty': '750 ml', 'price_per_kg': 1.86}
# {'description': 'Bauli, il Croissant al cioccolato 6 pezzi 300 g', 'category': 'Confezionati alimentari', 'price': 2.08, 'qty': '300 g', 'price_per_kg': 6.94}
# {'description': 'Cuore di Sardegna, Il Savoiardo morbido 250 g', 'category': 'Confezionati alimentari', 'price': 2.33, 'qty': '250 g', 'price_per_kg': 6.52}
# {'description': 'Barilla, Penne Rigate n. 73 pasta di semola di grano duro 1 kg', 'category': 'Confezionati alimentari', 'price': 1.45, 'qty': '1 kg', 'price_per_kg': 1.45}
# {'description': 'Kinder, Délice 10 pezzi 390 g', 'category': 'Confezionati alimentari', 'price': 2.99, 'qty': '390 g', 'price_per_kg': 7.67}
# {'description': 'Barilla, Mezze Penne Rigate n. 70 pasta di semola di grano duro 1 kg', 'category': 'Confezionati alimentari', 'price': 1.45, 'qty': '1 kg', 'price_per_kg': 1.45}
# {'description': 'Nescafé, Caffè per latte caffè solubile 100 g', 'category': 'Confezionati alimentari', 'price': 2.99, 'qty': '100 g', 'price_per_kg': 29.9}
# {'description': 'Kinder, Colazione più 10 pezzi 290 g', 'category': 'Confezionati alimentari', 'price': 2.89, 'qty': '290 g', 'price_per_kg': 9.97}
# {'description': 'San Carlo, Rodeo 120 g', 'category': 'Confezionati alimentari', 'price': 1.41, 'qty': '120 g', 'price_per_kg': 11.76}
# {'description': 'De Cecco, Spaghetti n. 12 pasta di semola di grano duro 500 g', 'category': 'Confezionati alimentari', 'price': 1.35, 'qty': '500 g', 'price_per_kg': 1.34}
# {'description': 'Pata, La Patatina Metodo Artigianale 150 g', 'category': 'Confezionati alimentari', 'price': 1.24, 'qty': '150 g', 'price_per_kg': 6.61}
# {'description': 'Mutti, salsa pronta classica 300 g', 'category': 'Confezionati alimentari', 'price': 1.75, 'qty': '300 g', 'price_per_kg': 5.84}
# {'description': 'Citterio, Un Due Tris! Salame, con formaggio e crostini 100 g', 'category': 'latticini_e_formaggi', 'price': 2.55, 'qty': '100 g', 'price_per_kg': 25.5}
# {'description': 'Kinder, Cioccolato conf. 24x12,5 g', 'category': 'Confezionati alimentari', 'price': 3.99, 'qty': '300 g', 'price_per_kg': 13.31}
# {'description': 'Frisk, Clean Breath Peppermint 50 Mints caramelle dure senza zucchero senza glutine 35 g', 'category': 'Confezionati alimentari', 'price': 2.08, 'qty': '35 g', 'price_per_kg': 59.43}
# {'description': 'Pedon, Easyglut farina di riso 250 g', 'category': 'Confezionati alimentari', 'price': 1.05, 'qty': '250 g', 'price_per_kg': 4.2}
# {'description': 'Kinder, Cereali conf. 6x23,5 g', 'category': 'Confezionati alimentari', 'price': 2.79, 'qty': '141 g', 'price_per_kg': 19.79}
# {'description': 'Lavazza, Qualità Rossa conf. 2x250 g', 'category': 'Confezionati alimentari', 'price': 6.25, 'qty': '500 g', 'price_per_kg': 12.5}
# {'description': 'Saiwa, Cipster The Original conf. 7x22 g', 'category': 'Confezionati alimentari', 'price': 2.43, 'qty': '154 g', 'price_per_kg': 15.78}
# {'description': 'Novi, CremaNovi 45% nocciole 200 g', 'category': 'Confezionati alimentari', 'price': 4.26, 'qty': '200 g', 'price_per_kg': 21.3}
# {'description': 'Splendid, Classico conf. 2x250 g', 'category': 'Confezionati alimentari', 'price': 4.57, 'qty': '500 g', 'price_per_kg': 9.14}
# {'description': 'Il Molino Chiavazza, Amizea amido di mais 250 g', 'category': 'Confezionati alimentari', 'price': 0.79, 'qty': '250 g', 'price_per_kg': 3.16}
# {'description': 'Pfanni, preparato per purè di patate in fiocchi conf. 4x75 g', 'category': 'Confezionati alimentari', 'price': 3, 'qty': '300 g', 'price_per_kg': 10.01}
# {'description': 'Cirio, I Classici passata verace di pomodoro 700 g', 'category': 'Confezionati alimentari', 'price': 1.39, 'qty': '700 g', 'price_per_kg': 1.99}
# {'description': 'Nutella, B-ready conf. 6x22 g', 'category': 'Confezionati alimentari', 'price': 1.99, 'qty': '132 g', 'price_per_kg': 15.08}
# {'description': 'Mulino Bianco, Rigoli 800 g', 'category': 'Confezionati alimentari', 'price': 2.99, 'qty': '800 g', 'price_per_kg': 3.74}
# {'description': 'Bauli, il Croissant alla ciliegia 6 pezzi 300 g', 'category': 'Confezionati alimentari', 'price': 2.08, 'qty': '300 g', 'price_per_kg': 6.94}
# {'description': 'Golia, Frutta C caramelle ripiene senza glutine senza zucchero conf. 2x46 g', 'category': 'Confezionati alimentari', 'price': 2.15, 'qty': '92 g', 'price_per_kg': 23.4}
# {'description': 'Nutella, B-ready conf. 10x22 g', 'category': 'Confezionati alimentari', 'price': 2.99, 'qty': '220 g', 'price_per_kg': 13.6}
# {'description': "Delicius, filetti di sgombro all'olio di oliva 90 g", 'category': 'Confezionati alimentari', 'price': 2.17, 'qty': '90 g', 'price_per_kg': 24.12}
# {'description': 'Barilla, sugo al basilico 500 g', 'category': 'Confezionati alimentari', 'price': 1.64, 'qty': '500 g', 'price_per_kg': 3.28}
# {'description': 'Mulino Bianco, Flauti al latte 8 pezzi 280 g', 'category': 'Confezionati alimentari', 'price': 2.19, 'qty': '280 g', 'price_per_kg': 7.83}
# {'description': '3 Cuochi, zafferano conf. 4x0,15 g', 'category': 'Confezionati alimentari', 'price': 5.46, 'qty': '600 mg', 'price_per_kg': 9100.0}
# {'description': 'Misura, Fibrextra biscotti integrali 630 g', 'category': 'Confezionati alimentari', 'price': 3.79, 'qty': '630 g', 'price_per_kg': 6.02}
# {'description': 'Pavesi, Ringo vaniglia 165 g', 'category': 'Confezionati alimentari', 'price': 1.29, 'qty': '165 g', 'price_per_kg': 7.82}
# {'description': 'Loacker, Napolitaner wafer con nocciole italiane 175 g', 'category': 'Confezionati alimentari', 'price': 1.39, 'qty': '175 g', 'price_per_kg': 7.95}
# {'description': 'Mulino Bianco, Ritornelli 700 g', 'category': 'Confezionati alimentari', 'price': 3.19, 'qty': '700 g', 'price_per_kg': 4.56}
# {'description': 'Star, Il mio Brodo di manzo 1 l', 'category': 'Confezionati alimentari', 'price': 1.99, 'qty': '1000 ml', 'price_per_kg': 1.99}
# {'description': 'Parmareggio, Snack & Vai! Parmigiano Reggiano DOP e tarallini Gran Pavesi 37 g', 'category': 'latticini_e_formaggi', 'price': 1, 'qty': '37 g', 'price_per_kg': 27.03}
# {'description': 'Snack In Love, semi di zucca tostati e salati 250 g', 'category': 'Confezionati alimentari', 'price': 1.77, 'qty': '250 g', 'price_per_kg': 7.08}
# {'description': 'Barilla, Integrale Fusilli pasta di semola di grano duro 500 g', 'category': 'Confezionati alimentari', 'price': 1.09, 'qty': '500 g', 'price_per_kg': 2.18}
# {'description': 'Novi, nocciolato fondente 130 g', 'category': 'Confezionati alimentari', 'price': 2.49, 'qty': '130 g', 'price_per_kg': 19.16}
# {'description': 'Barilla, ragù alla bolognese 295 g', 'category': 'Confezionati alimentari', 'price': 1.79, 'qty': '295 g', 'price_per_kg': 4.04}
# {'description': 'Mutti, Sugo Semplice con basilico 280 g', 'category': 'Confezionati alimentari', 'price': 1.99, 'qty': '280 g', 'price_per_kg': 7.11}
# {'description': 'Misura, Privolat biscotti con gocce di cioccolato 320 g', 'category': 'Confezionati alimentari', 'price': 2.7, 'qty': '320 g', 'price_per_kg': 8.44}
# {'description': 'Eridania, Zefiro zucchero a velo vaniglinato 140 g', 'category': 'Confezionati alimentari', 'price': 0.81, 'qty': '140 g', 'price_per_kg': 5.79}
# {'description': 'Asolo Dolce, Fogliette 200 g', 'category': 'Confezionati alimentari', 'price': 0.99, 'qty': '200 g', 'price_per_kg': 4.95}
# {'description': 'Star, Il Mio Dado Classico 30 dadi 300 g', 'category': 'Confezionati alimentari', 'price': 3.89, 'qty': '300 g', 'price_per_kg': 12.97}
# {'description': 'Pan Di Stelle, La torta 435 g', 'category': 'Confezionati alimentari', 'price': 4.75, 'qty': '435 g', 'price_per_kg': 10.92}
# {'description': 'Galbusera, ColCuore frollino integrale con fibre di cereali conf. 6x50 g', 'category': 'Confezionati alimentari', 'price': 2.19, 'qty': '300 g', 'price_per_kg': 5.84}
# {'description': 'Artebianca, Fior di Riso 400 g', 'category': 'Confezionati alimentari', 'price': 3.53, 'qty': '400 g', 'price_per_kg': 8.83}
# {'description': 'Rummo, Spaghetti n. 3 pasta di semola di grano duro 500 g', 'category': 'Confezionati alimentari', 'price': 1.25, 'qty': '500 g', 'price_per_kg': 2.5}
# {'description': 'Rummo, Penne Rigate n. 66 pasta di semola di grano duro 500 g', 'category': 'Confezionati alimentari', 'price': 1.25, 'qty': '500 g', 'price_per_kg': 2.5}
# {'description': 'Rizzoli, Riserva di Famiglia filetti di alici Mar Adriatico in olio di oliva 40 g', 'category': 'Confezionati alimentari', 'price': 1.5, 'qty': '40 g', 'price_per_kg': 37.5}
# {'description': 'Mulino Bianco, Pane + Cioccolato al latte 8 pezzi 300 g', 'category': 'Confezionati alimentari', 'price': 2.69, 'qty': '300 g', 'price_per_kg': 6.31}
# {'description': 'Misura, Fibrextra 6 Cornetti Integrali al Miele 300 g', 'category': 'Confezionati alimentari', 'price': 2.69, 'qty': '300 g', 'price_per_kg': 8.97}
# {'description': 'Saiwa, Mini Ritz conf. 6x40 g', 'category': 'Confezionati alimentari', 'price': 2.01, 'qty': '240 g', 'price_per_kg': 8.38}
# {'description': 'Lindt, fondente classico 100 g', 'category': 'Confezionati alimentari', 'price': 1.59, 'qty': '100 g', 'price_per_kg': 15.9}
# {'description': 'Calvé, Raffinata maionese 150 ml', 'category': 'Confezionati alimentari', 'price': 1.19, 'qty': '150 ml', 'price_per_kg': 7.94}
# {'description': 'Fidèl, caffè istantaneo 100 g', 'category': 'Confezionati alimentari', 'price': 1.7, 'qty': '100 g', 'price_per_kg': 17.0}
# {'description': 'Colussi, ZuppaLatte 500 g', 'category': 'Confezionati alimentari', 'price': 2.09, 'qty': '500 g', 'price_per_kg': 4.18}
# {'description': 'Star, il Mio Dado Vegetale 20 dadi 200 g', 'category': 'Confezionati alimentari', 'price': 1.85, 'qty': '200 g', 'price_per_kg': 9.25}
# {'description': 'Galbusera, BuoniCosì conf. 8x55 g', 'category': 'Confezionati alimentari', 'price': 2.99, 'qty': '440 g', 'price_per_kg': 6.8}
# {'description': 'Ferrero, Nutella 800 g', 'category': 'Confezionati alimentari', 'price': 5.49, 'qty': '800 g', 'price_per_kg': 6.87}
# {'description': 'Moro, Pizzoccheri della Valtellina IGP di grano saraceno 700 g', 'category': 'Confezionati alimentari', 'price': 1.79, 'qty': '700 g', 'price_per_kg': 2.56}
# {'description': 'Pavesi, Gocciole extra dark 400 g', 'category': 'Confezionati alimentari', 'price': 2.35, 'qty': '400 g', 'price_per_kg': 4.98}
# {'description': 'Lindt, latte 100 g', 'category': 'Confezionati alimentari', 'price': 1.59, 'qty': '100 g', 'price_per_kg': 15.9}
# {'description': 'Saiwa, Oro 5 Cereali 400 g', 'category': 'Confezionati alimentari', 'price': 1.99, 'qty': '400 g', 'price_per_kg': 3.98}
# {'description': 'Gentilini, fette biscottate 185 g', 'category': 'Confezionati alimentari', 'price': 1.75, 'qty': '185 g', 'price_per_kg': 9.46}
# {'description': 'Giacomini, Aquilotto gelatina in fogli 25 g', 'category': 'Confezionati alimentari', 'price': 1.33, 'qty': '25 g', 'price_per_kg': 53.2}
# {'description': 'Rummo, Fusilli n. 48 pasta di semola di grano duro 500 g', 'category': 'Confezionati alimentari', 'price': 1.25, 'qty': '500 g', 'price_per_kg': 2.5}
